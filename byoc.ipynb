# %% [markdown]
# ## Bring Your Own Algorithm to SageMaker
#
#
# ###  Training
# a. [Bring Your Own Container](#byoc)
#
# b. [Training locally](#local_train)
#
# c. [Trigger remote training job](#remote_train)

# %% [markdown]
# ### BYOC (Bring Your Own Container) for CascadeTabNet
# <a name="byoc"></a>

# %% [markdown]
# * prepare necessry variables
# using `boto3` to get region and account_id for later usage - ECR uri construction

# %%
import boto3 

session = boto3.session.Session()
region = session.region_name
client = boto3.client("sts")
account_id = client.get_caller_identity()["Account"]
algorithm_name = "cascade-tab-net"

# %% [markdown]
# #### 3 elements to build bring your own container
# * `build_and_push.sh` is the script communicating with ECR
# * `Dockerfile` defines the training and serving environment
# * `code/train` and `code/serve` defines entry point of our container

# %%
# %%bash
# cd docker
# ./build_and_push.sh
# Out:
# 230755935769
# us-west-2
# Login Succeeded
# Login Succeeded
# 1.4.0-gpu-py36-cu101-ubuntu16.04: Pulling from pytorch-training
# Digest: sha256:0a352ccd7298c8039bea2d6dff533fd91df758dd7b42b08191db4cc9271fdff5
# Status: Image is up to date for 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training:1.4.0-gpu-py36-cu101-ubuntu16.04
# 763104351884.dkr.ecr.us-west-2.amazonaws.com/pytorch-training:1.4.0-gpu-py36-cu101-ubuntu16.04
# Sending build context to Docker daemon  6.656kB
# Step 1/19 : ARG BASE_IMG=${BASE_IMG}
# Step 2/19 : FROM ${BASE_IMG}
#  ---> 7c08530cf40c
# Step 3/19 : RUN pip install -q mmcv terminaltables
#  ---> Using cache
#  ---> d973e0ac87e8
# Step 4/19 : RUN git clone --branch v1.2.0 'https://github.com/open-mmlab/mmdetection.git'
#  ---> Using cache
#  ---> 6133b9597a09
# Step 5/19 : WORKDIR /mmdetection
#  ---> Using cache
#  ---> a7bae8fc407f
# Step 6/19 : ENV FORCE_CUDA="1"
#  ---> Using cache
#  ---> f86ae3b27d1d
# Step 7/19 : RUN pip install -r requirements/optional.txt
#  ---> Using cache
#  ---> e6c59f8c9406
# Step 8/19 : RUN python setup.py install
#  ---> Using cache
#  ---> 3d2d919ee16c
# Step 9/19 : RUN python setup.py develop
#  ---> Using cache
#  ---> 7edfdb5218d4
# Step 10/19 : RUN pip install -r requirements.txt
#  ---> Using cache
#  ---> e1bf9ab2de35
# Step 11/19 : RUN pip install pillow==6.2.1 mmcv==0.4.3 pycocotools
#  ---> Using cache
#  ---> c3ad91b707ca
# Step 12/19 : COPY download_model.sh .
#  ---> Using cache
#  ---> 9559ad7dd32d
# Step 13/19 : RUN ./download_model.sh
#  ---> Using cache
#  ---> 196e76f91ba2
# Step 14/19 : RUN echo "this step will be executed again if the value of FooBar Bar changes"
#  ---> Running in 3052c9278ac7
# this step will be executed again if the value of FooBar Bar changes
# Removing intermediate container 3052c9278ac7
#  ---> e9e0a2460b24
# Step 15/19 : WORKDIR /
#  ---> Running in 2ec2bd40a842
# Removing intermediate container 2ec2bd40a842
#  ---> 8720ba1c63f0
# Step 16/19 : RUN pip install gdown && gdown "https://drive.google.com/u/0/uc?id=1-QieHkR1Q7CXuBu4fp3rYrvDG9j26eFT"
#  ---> Running in 4f8e063e0134
# Collecting gdown
#   Downloading gdown-3.13.0.tar.gz (9.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.6/site-packages (from gdown) (4.56.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.12.0 in /opt/conda/lib/python3.6/site-packages (from gdown) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests[socks]>=2.12.0->gdown) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests[socks]>=2.12.0->gdown) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests[socks]>=2.12.0->gdown) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests[socks]>=2.12.0->gdown) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.6/site-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-3.13.0-py3-none-any.whl size=9034 sha256=1ed77d68f590fbbecb7f6175f79a1924672bfc6c6e10f474d6e6919fce3d0fc3
#   Stored in directory: /root/.cache/pip/wheels/6a/87/bd/09b16161b149fd6711ac76b5420d78ed58bd6a320e892117c3
# Successfully built gdown
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.0.12 gdown-3.13.0
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1-QieHkR1Q7CXuBu4fp3rYrvDG9j26eFT
# To: /epoch_36.pth
# 664MB [00:10, 64.6MB/s]
# Removing intermediate container 4f8e063e0134
#  ---> 1273dfcd66f1
# Step 17/19 : RUN git clone https://github.com/catwhiskers/CascadeTabNet.git
#  ---> Running in 1fc2d0aeab97
# Cloning into 'CascadeTabNet'...
# Removing intermediate container 1fc2d0aeab97
#  ---> edebc8efd15d
# Step 18/19 : COPY train /
#  ---> 4472e8a7cfb2
# Step 19/19 : ENV PATH="/:${PATH}"
#  ---> Running in 09ff871d1aeb
# Removing intermediate container 09ff871d1aeb
#  ---> 4d3fc0d21ccd
# Successfully built 4d3fc0d21ccd
# Successfully tagged cascade-tab-net:latest
# The push refers to repository [230755935769.dkr.ecr.us-west-2.amazonaws.com/cascade-tab-net]
# c9b0cbb37bac: Preparing
# 2bdae8e000b5: Preparing
# 3f379c656808: Preparing
# 8a8fe7066d43: Preparing
# 9eff5f26bb6b: Preparing
# 046128340da4: Preparing
# 37de227ae92b: Preparing
# 16bf1eec4555: Preparing
# ee425b115b72: Preparing
# 9c94ec558bbd: Preparing
# 5e67aa9d89d4: Preparing
# d0f21deaea3f: Preparing
# 5b0e79f22b0a: Preparing
# 279d81639928: Preparing
# 0bd4078ed472: Preparing
# 046128340da4: Waiting
# 5acc6be562d3: Preparing
# 16bf1eec4555: Waiting
# 35f0dfa230f2: Preparing
# 37de227ae92b: Waiting
# 828cc96b08b7: Preparing
# fc48544f4ebb: Preparing
# ee425b115b72: Waiting
# cb2f5d086a57: Preparing
# 0ab411b8e8b2: Preparing
# 299b9409e4be: Preparing
# 0e52c97daa6a: Preparing
# 9c94ec558bbd: Waiting
# 78bdccc357ec: Preparing
# 5e67aa9d89d4: Waiting
# b96ecc559257: Preparing
# d4d5a6ee3134: Preparing
# 70510d78ca1b: Preparing
# b6a80f31749b: Preparing
# 679bff006560: Preparing
# cfd57e38f2d8: Preparing
# 3b672ea48d23: Preparing
# 17b762fe140e: Preparing
# 85dd6d30da44: Preparing
# 7b54d96b0113: Preparing
# 1ff515d3a62b: Preparing
# 279d81639928: Waiting
# d0f21deaea3f: Waiting
# 0bd4078ed472: Waiting
# 5b0e79f22b0a: Waiting
# 0ab411b8e8b2: Waiting
# 828cc96b08b7: Waiting
# 299b9409e4be: Waiting
# fc48544f4ebb: Waiting
# 5acc6be562d3: Waiting
# b96ecc559257: Waiting
# 0e52c97daa6a: Waiting
# cb2f5d086a57: Waiting
# 78bdccc357ec: Waiting
# 35f0dfa230f2: Waiting
# d4d5a6ee3134: Waiting
# cfd57e38f2d8: Waiting
# 679bff006560: Waiting
# 3b672ea48d23: Waiting
# b6a80f31749b: Waiting
# 70510d78ca1b: Waiting
# 85dd6d30da44: Waiting
# 17b762fe140e: Waiting
# 7b54d96b0113: Waiting
# b88239edd0b8: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 1ff515d3a62b: Waiting
# b88239edd0b8: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 935c56d8b3f9: Waiting
# 697949baa658: Waiting
# c9b0cbb37bac: Layer already exists
# 9eff5f26bb6b: Layer already exists
# 8a8fe7066d43: Layer already exists
# 046128340da4: Layer already exists
# 37de227ae92b: Layer already exists
# 16bf1eec4555: Layer already exists
# ee425b115b72: Layer already exists
# 5e67aa9d89d4: Layer already exists
# 9c94ec558bbd: Layer already exists
# d0f21deaea3f: Layer already exists
# 279d81639928: Layer already exists
# 5b0e79f22b0a: Layer already exists
# 0bd4078ed472: Layer already exists
# 5acc6be562d3: Layer already exists
# 35f0dfa230f2: Layer already exists
# 828cc96b08b7: Layer already exists
# fc48544f4ebb: Layer already exists
# cb2f5d086a57: Layer already exists
# 0ab411b8e8b2: Layer already exists
# 299b9409e4be: Layer already exists
# 0e52c97daa6a: Layer already exists
# 78bdccc357ec: Layer already exists
# b96ecc559257: Layer already exists
# d4d5a6ee3134: Layer already exists
# 70510d78ca1b: Layer already exists
# b6a80f31749b: Layer already exists
# 679bff006560: Layer already exists
# cfd57e38f2d8: Layer already exists
# 3b672ea48d23: Layer already exists
# 17b762fe140e: Layer already exists
# 85dd6d30da44: Layer already exists
# 7b54d96b0113: Layer already exists
# 1ff515d3a62b: Layer already exists
# b88239edd0b8: Layer already exists
# 5276d2b930fc: Layer already exists
# e6feec0db89a: Layer already exists
# 697949baa658: Layer already exists
# 935c56d8b3f9: Layer already exists
# 2bdae8e000b5: Pushed
# 3f379c656808: Pushed
# latest: digest: sha256:0fbd5156e7275985db008a1fff3d9a9f97f0c491276f504bbd54d5e1b2905650 size: 8733
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %%
# !cat docker/Dockerfile
# Out:
# ARG BASE_IMG=${BASE_IMG}
# FROM ${BASE_IMG}
# RUN pip install -q mmcv terminaltables
# RUN git clone --branch v1.2.0 'https://github.com/open-mmlab/mmdetection.git'
# WORKDIR /mmdetection
# ENV FORCE_CUDA="1"
# RUN pip install -r requirements/optional.txt
# RUN python setup.py install
# RUN python setup.py develop
# RUN pip install -r requirements.txt
# RUN pip install pillow==6.2.1 mmcv==0.4.3 pycocotools
# COPY download_model.sh .
# RUN ./download_model.sh

# %%
# !cat docker/build_and_push.sh
# Out:
# #!/bin/bash
#
# # The name of our algorithm
# algorithm_name=cascade-tab-net
#
# #cd container
# # get information - account and region, required by ECR https://aws.amazon.com/ecr/
# account=$(aws sts get-caller-identity --query Account --output text)
# echo $account
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
# echo $region
#
#
# # derive fullname of docker image
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# # Get the login command from ECR in order to pull down the SageMaker TensorFlow image
# $(aws ecr get-login --registry-ids 763104351884 --region ${region} --no-include-email)
#
# # get the fullname of deep learning container image
# base_img='763104351884.dkr.ecr.'$region'.amazonaws.com/pytorch-training:1.4.0-gpu-py36-cu101-ubuntu16.04'
# docker pull $base_img
# docker build  -t ${algorithm_name} -f Dockerfile  --build-arg BASE_IMG="${base_img}" .
# docker tag ${algorithm_name} ${fullname}
# docker push ${fullname}

# %% [markdown]
# * construct image uri by account_id, region and algorithm_name

# %%
image_uri=f"{account_id}.dkr.ecr.{region}.amazonaws.com/{algorithm_name}"
image_uri
# Out:
# '230755935769.dkr.ecr.us-west-2.amazonaws.com/cascade-tab-net'

# %% [markdown]
# * prepare necessary variables/object for training

# %%
import sagemaker 
session = sagemaker.session.Session()
bucket = session.default_bucket()

# %%
from sagemaker import get_execution_role

role = get_execution_role()
print(role)

s3_path = f"s3://{bucket}/data/icdar_table_cells_dataset"
s3_path
# Out:
# arn:aws:iam::230755935769:role/SageMakerExecutionRoleMLOps
# 's3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset'

# %% [markdown]
# ### Dataset Description -
#
# Dataset used here is manually labeled by CascadeTabNet Team, here is the [link](https://drive.google.com/drive/folders/1mNDbbhu-Ubz87oRDjdtLA4BwQwwNOO-G)

# %%
# s3://tomofun-audio-classification-yianc
# data/data.zip
# !aws s3 cp --recursive ~/SageMaker/icdar_table_cells_dataset $s3_path
# Out:
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10003.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10003.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10000.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10000.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10005.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10005.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10001.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10001.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10007.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10007.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10006.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10006.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10010.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10010.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10002.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10002.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10009.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10009.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10014.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10014.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10004.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10004.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10012.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10012.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10013.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10013.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10008.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10008.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10016.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10016.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10017.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10017.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10024.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10024.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10021.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10021.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10020.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10020.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10011.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10011.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10023.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10023.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10019.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10019.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10022.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10022.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10015.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10015.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10028.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10028.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10025.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10025.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10030.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10030.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10033.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10033.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10018.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10018.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10027.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10027.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10029.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10029.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10032.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10032.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10026.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10026.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10034.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10034.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10031.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10031.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10036.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10036.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10042.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10042.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10035.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10035.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10040.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10040.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10041.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10041.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10038.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10038.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10044.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10044.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10039.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10039.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10037.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10037.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10051.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10051.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10043.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10043.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10045.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10045.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10047.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10047.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10049.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10049.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10046.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10046.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10050.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10050.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10055.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10055.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10056.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10056.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10048.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10048.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10052.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10052.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10054.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10054.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10060.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10060.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10053.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10053.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10062.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10062.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10061.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10061.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10059.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10059.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10058.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10058.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10063.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10063.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10064.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10064.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10068.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10068.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10066.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10066.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10069.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10069.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10071.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10071.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10072.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10072.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10065.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10065.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10067.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10067.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10057.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10057.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10070.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10070.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10074.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10074.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10079.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10079.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10080.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10080.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10073.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10073.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10075.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10075.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10076.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10076.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10078.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10078.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10086.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10086.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10077.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10077.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10089.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10089.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10082.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10082.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10083.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10083.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10084.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10084.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10087.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10087.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10085.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10085.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10081.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10081.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10088.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10088.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10094.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10094.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10097.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10097.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10092.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10092.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10095.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10095.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10091.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10091.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10093.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10093.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10099.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10099.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10090.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10090.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10102.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10102.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10098.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10098.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10109.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10109.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10106.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10106.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10104.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10104.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10096.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10096.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10105.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10105.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10111.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10111.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10103.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10103.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10107.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10107.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10100.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10100.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10136.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10136.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10110.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10110.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10121.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10121.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10128.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10128.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10101.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10101.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10132.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10132.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10142.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10142.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10163.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10163.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10147.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10147.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10108.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10108.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10156.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10156.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10152.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10152.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10155.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10155.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10177.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10177.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10171.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10171.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10158.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10158.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10150.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10150.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10153.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10153.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10196.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10196.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10190.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10190.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10234.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10234.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10246.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10246.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10176.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10176.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10214.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10214.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10191.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10191.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10184.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10184.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10249.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10249.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10173.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10173.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10256.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10256.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10259.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10259.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10251.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10251.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10253.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10253.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10252.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10252.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10262.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10262.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10255.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10255.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10261.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10261.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10254.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10254.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10265.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10265.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10260.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10260.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10258.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10258.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10257.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10257.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10267.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10267.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10266.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10266.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10268.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10268.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10264.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10264.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10271.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10271.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10263.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10263.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10276.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10276.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10270.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10270.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10269.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10269.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10272.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10272.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10273.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10273.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10274.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10274.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10275.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10275.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10278.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10278.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10279.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10279.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10280.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10280.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10281.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10281.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10286.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10286.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10284.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10284.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10277.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10277.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10283.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10283.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10291.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10291.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10285.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10285.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10292.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10292.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10293.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10293.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10290.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10290.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10282.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10282.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10287.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10287.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10288.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10288.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10296.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10296.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10297.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10297.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10295.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10295.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10299.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10299.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10294.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10294.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10301.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10301.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10289.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10289.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10298.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10298.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10302.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10302.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10303.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10303.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10300.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10300.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10311.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10311.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10310.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10310.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10304.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10304.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10305.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10305.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10309.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10309.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10306.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10306.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10307.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10307.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10314.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10314.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10308.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10308.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10313.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10313.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10312.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10312.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10315.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10315.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10316.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10316.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10317.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10317.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10319.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10319.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10322.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10322.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10326.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10326.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10328.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10328.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10324.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10324.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10321.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10321.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10320.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10320.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10318.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10318.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10323.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10323.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10325.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10325.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10329.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10329.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10327.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10327.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10334.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10334.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10331.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10331.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10336.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10336.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10332.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10332.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10337.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10337.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10330.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10330.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10339.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10339.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10340.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10340.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10341.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10341.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10335.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10335.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10333.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10333.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10345.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10345.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10338.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10338.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10344.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10344.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10343.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10343.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10350.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10350.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10342.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10342.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10348.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10348.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10351.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10351.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10357.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10357.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10352.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10352.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10347.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10347.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10355.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10355.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10353.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10353.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10358.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10358.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10346.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10346.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10356.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10356.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10359.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10359.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10408.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10408.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10349.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10349.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10354.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10354.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10405.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10405.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10360.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10360.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10415.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10415.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10411.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10411.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10410.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10410.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10424.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10424.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10413.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10413.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10417.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10417.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10412.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10412.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10425.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10425.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10419.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10419.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10427.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10427.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10407.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10407.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10426.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10426.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10416.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10416.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10431.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10431.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10428.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10428.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10434.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10434.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10452.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10452.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10433.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10433.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10435.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10435.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10429.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10429.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10446.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10446.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10438.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10438.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10457.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10457.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10454.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10454.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10444.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10444.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10451.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10451.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10458.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10458.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10456.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10456.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10455.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10455.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10460.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10460.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10462.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10462.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10470.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10470.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10467.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10467.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10468.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10468.jpg
# upload: ../icdar_table_cells_dataset/chunk_images/cTDaR_t10459.jpg to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/chunk_images/cTDaR_t10459.jpg
# ...
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10435.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10435.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10454.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10454.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10433.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10433.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10457.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10457.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10458.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10458.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10455.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10455.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10424.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10424.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10459.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10459.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10452.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10452.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10464.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10464.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10461.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10461.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10468.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10468.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10460.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10460.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10465.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10465.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10462.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10462.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10472.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10472.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10471.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10471.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10467.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10467.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10473.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10473.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10476.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10476.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10469.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10469.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10470.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10470.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10481.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10481.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10482.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10482.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10475.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10475.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10483.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10483.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10474.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10474.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10487.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10487.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10478.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10478.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10486.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10486.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10480.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10480.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10488.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10488.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10479.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10479.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10484.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10484.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10490.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10490.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10485.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10485.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10489.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10489.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10495.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10495.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10491.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10491.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10496.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10496.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10499.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10499.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10502.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10502.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10501.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10501.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10506.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10506.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10505.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10505.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10500.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10500.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10508.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10508.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10498.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10498.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10493.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10493.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10494.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10494.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10511.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10511.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10510.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10510.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10512.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10512.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10507.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10507.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10517.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10517.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10515.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10515.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10514.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10514.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10504.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10504.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10519.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10519.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10524.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10524.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10526.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10526.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10531.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10531.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10520.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10520.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10525.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10525.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10528.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10528.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10532.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10532.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10513.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10513.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10518.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10518.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10538.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10538.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10539.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10539.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10541.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10541.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10533.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10533.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10534.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10534.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10545.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10545.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10535.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10535.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10547.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10547.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10536.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10536.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10543.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10543.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10549.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10549.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10529.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10529.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10552.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10552.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10548.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10548.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10561.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10561.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10557.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10557.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10562.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10562.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10551.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10551.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10559.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10559.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10555.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10555.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10553.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10553.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10554.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10554.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10566.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10566.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10567.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10567.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10569.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10569.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10563.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10563.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10568.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10568.xml
# upload: ../icdar_table_cells_dataset/orig_chunk/cTDaR_t10565.xml to s3://sagemaker-us-west-2-230755935769/data/icdar_table_cells_dataset/orig_chunk/cTDaR_t10565.xml

# %% [markdown]
# ### Train model in a docker container with terminal interface
# <a name="local_train"></a>

# %% [markdown]
# * start container in interactive mode
# ```
# IMAGE_ID=$(sudo docker images --filter=reference=cascade-tab-net --format "{{.ID}}")
# nvidia-docker run -it -v $PWD:$PWD --shm-size=4096m $IMAGE_ID bash
# ```
# * train model based on README.md
# ```
# cd /home/ec2-user/SageMaker/CascadeTabNet/
# python /mmdetection/tools/train.py  Config/cascade_mask_rcnn_hrnetv2p_w32_20e_smnb.py
#
# cd /home/ec2-user/SageMaker/CascadeTabNet/Table Structure Recognition/
# python main.py
# ```

# %%
from datetime import datetime
now = datetime.now()
timestamp = datetime.timestamp(now)
job_name = "cascadetabnet-{}".format(str(int(timestamp))) 
job_name
# Out:
# 'cascadetabnet-1627990041'

# %% [markdown]
# ### Start SageMaker Training Job
# <a name="remote_train"></a>
# * sagemaker training jobs can run either locally or remotely

# %%
mode = 'remote'
if mode == 'local':
    csess = sagemaker.local.LocalSession()
else:    
    csess = session

print(csess)
estimator = sagemaker.estimator.Estimator( 
                        role=role,
                        image_uri=image_uri,
                        instance_count=1,
#                         instance_type='local_gpu',
                        instance_type='ml.p3.8xlarge',
                        sagemaker_session=csess,
                        volume_size=100, 
                        debugger_hook_config=False
                   )
# Out:
# <sagemaker.session.Session object at 0x7fdcb1aefe80>

# %%
estimator.fit(inputs={"icdar_table_cells_dataset":s3_path}, job_name=job_name)
# Out:
# 2021-08-03 11:27:25 Starting - Starting the training job...
# 2021-08-03 11:27:49 Starting - Launching requested ML instancesProfilerReport-1627990044: InProgress
# .........
# 2021-08-03 11:29:09 Starting - Preparing the instances for training...
# 2021-08-03 11:29:55 Downloading - Downloading input data...
# 2021-08-03 11:30:16 Training - Downloading the training image....................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-08-03 11:33:40,962 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.6.13 |Anaconda, Inc.| (default, Feb 23 2021, 21:15:04) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2,3: Tesla V100-SXM2-16GB
# GCC: gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609
# PyTorch: 1.4.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 5.4
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.21.1 (Git Hash 5d26ceb1d48e15ab61e6d53cea948c18964036de)
#   - OpenMP 201307 (a.k.a. OpenMP 4.0)
#   - NNPACK is enabled
#   - CUDA Runtime 10.1
#   - NVCC architecture flags: -gencode;arch=compute_35,code=sm_35;-gencode;arch=compute_52,code=sm_52;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_70,code=compute_70
#   - CuDNN 7.6.5
#     - Built with CuDNN 7.6.3
#   - Magma 2.5.1
#   - Build settings: BLAS=MKL, BUILD_NAMEDTENSOR=OFF, BUILD_TYPE=Release, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -fopenmp -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -O2 -fPIC -Wno-narrowing -Wall -Wextra -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math, FORCE_FALLBACK_CUDA_MPI=1, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, USE_CUDA=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=ON, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_STATIC_DISPATCH=OFF,
#
# TorchVision: 0.5.0
# OpenCV: 4.5.3
# MMCV: 0.4.3
# MMDetection: 1.2.0+0f33c08
# MMDetection Compiler: GCC 5.4
# MMDetection CUDA Compiler: 10.1
# ------------------------------------------------------------
#
# 2021-08-03 11:33:40,963 - mmdet - INFO - Distributed training: False
# 2021-08-03 11:33:40,963 - mmdet - INFO - Config:
# /CascadeTabNet/Config/cascade_mask_rcnn_hrnetv2p_w32_20e_sm_tr.py
# # model settings
# model = dict(
#     type='CascadeRCNN',
#     num_stages=3,
#     pretrained='open-mmlab://msra/hrnetv2_w32',
#     backbone=dict(
#         type='HRNet',
#         extra=dict(
#             stage1=dict(
#                 num_modules=1,
#                 num_branches=1,
#                 block='BOTTLENECK',
#                 num_blocks=(4, ),
#                 num_channels=(64, )),
#             stage2=dict(
#                 num_modules=1,
#                 num_branches=2,
#                 block='BASIC',
#                 num_blocks=(4, 4),
#                 num_channels=(32, 64)),
#             stage3=dict(
#                 num_modules=4,
#                 num_branches=3,
#                 block='BASIC',
#                 num_blocks=(4, 4, 4),
#                 num_channels=(32, 64, 128)),
#             stage4=dict(
#                 num_modules=3,
#                 num_branches=4,
#                 block='BASIC',
#                 num_blocks=(4, 4, 4, 4),
#                 num_channels=(32, 64, 128, 256)))),
#     neck=dict(type='HRFPN', in_channels=[32, 64, 128, 256], out_channels=256),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_scales=[8],
#         anchor_ratios=[0.5, 1.0, 2.0],
#         anchor_strides=[4, 8, 16, 32, 64],
#         target_means=[.0, .0, .0, .0],
#         target_stds=[1.0, 1.0, 1.0, 1.0],
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='SmoothL1Loss', beta=1.0 / 9.0, loss_weight=1.0)),
#     bbox_roi_extractor=dict(
#         type='SingleRoIExtractor',
#         roi_layer=dict(type='RoIAlign', out_size=7, sample_num=2),
#         out_channels=256,
#         featmap_strides=[4, 8, 16, 32]),
#     bbox_head=[
#         dict(
#             type='SharedFCBBoxHead',
#             num_fcs=2,
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=81,
#             target_means=[0., 0., 0., 0.],
#             target_stds=[0.1, 0.1, 0.2, 0.2],
#             reg_class_agnostic=True,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0)),
#         dict(
#             type='SharedFCBBoxHead',
#             num_fcs=2,
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=81,
#             target_means=[0., 0., 0., 0.],
#             target_stds=[0.05, 0.05, 0.1, 0.1],
#             reg_class_agnostic=True,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0)),
#         dict(
#             type='SharedFCBBoxHead',
#             num_fcs=2,
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=81,
#             target_means=[0., 0., 0., 0.],
#             target_stds=[0.033, 0.033, 0.067, 0.067],
#             reg_class_agnostic=True,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0))
#     ],
#     mask_roi_extractor=dict(
#         type='SingleRoIExtractor',
#         roi_layer=dict(type='RoIAlign', out_size=14, sample_num=2),
#         out_channels=256,
#         featmap_strides=[4, 8, 16, 32]),
#     mask_head=dict(
#         type='FCNMaskHead',
#         num_convs=4,
#         in_channels=256,
#         conv_out_channels=256,
#         num_classes=81,
#         loss_mask=dict(
#             type='CrossEntropyLoss', use_mask=True, loss_weight=1.0)))
# # model training and testing settings
# train_cfg = dict(
#     rpn=dict(
#         assigner=dict(
#             type='MaxIoUAssigner',
#             pos_iou_thr=0.7,
#             neg_iou_thr=0.3,
#             min_pos_iou=0.3,
#             ignore_iof_thr=-1),
#         sampler=dict(
#             type='RandomSampler',
#             num=256,
#             pos_fraction=0.5,
#             neg_pos_ub=-1,
#             add_gt_as_proposals=False),
#         allowed_border=0,
#         pos_weight=-1,
#         debug=False),
#     rpn_proposal=dict(
#         nms_across_levels=False,
#         nms_pre=2000,
#         nms_post=2000,
#         max_num=2000,
#         nms_thr=0.7,
#         min_bbox_size=0),
#     rcnn=[
#         dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False),
#         dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.6,
#                 neg_iou_thr=0.6,
#                 min_pos_iou=0.6,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False),
#         dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.7,
#                 min_pos_iou=0.7,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)
#     ],
#     stage_loss_weights=[1, 0.5, 0.25])
# test_cfg = dict(
#     rpn=dict(
#         nms_across_levels=False,
#         nms_pre=1000,
#         nms_post=1000,
#         max_num=1000,
#         nms_thr=0.7,
#         min_bbox_size=0),
#     rcnn=dict(
#         score_thr=0.05,
#         nms=dict(type='nms', iou_thr=0.5),
#         max_per_img=100,
#         mask_thr_binary=0.5))
# # dataset settings
# dataset_type = 'CocoDataset'
# # data_root = '/content/drive/My Drive/Mmdetection/'
# data_root = '/opt/ml/input/data/'
# model_root = '/opt/ml/model/'
#
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(type='Normalize', **img_norm_cfg),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks']),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(type='Normalize', **img_norm_cfg),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img']),
#         ])
# ]
# data = dict(
#     imgs_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type=dataset_type,
#         ann_file=data_root+'icdar_table_cells_dataset/instances_cell_annotations2014.json',
#         img_prefix=data_root+'icdar_table_cells_dataset/chunk_images/',
#         pipeline=train_pipeline),
#     val=dict(
#         type=dataset_type,
#         ann_file=data_root+'icdar_table_cells_dataset/instances_cell_annotations2014.json',
#         img_prefix=data_root+'icdar_table_cells_dataset/chunk_images/',
#         pipeline=test_pipeline),
#     test=dict(
#         type=dataset_type,
#         ann_file=data_root+'icdar_table_cells_dataset/instances_cell_annotations2014.json',
#         img_prefix=data_root+'icdar_table_cells_dataset/chunk_images/',
#         pipeline=test_pipeline))
# # evaluation = dict(interval=1, metric=['bbox'])
# # optimizer
# optimizer = dict(type='SGD', lr=0.0012, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=dict(max_norm=35, norm_type=2))
# # learning policy
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=1.0 / 3,
#     step=[16, 19])
# checkpoint_config = dict(interval=1,create_symlink=False)
# # yapf:disable
# log_config = dict(
#     interval=50,
#     hooks=[
#         dict(type='TextLoggerHook'),
#         # dict(type='TensorboardLoggerHook')
#     ])
# # yapf:enable
# # runtime settings
# total_epochs = 48
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# work_dir = model_root+'Mmdetection/new_chunk_cascade_mask_rcnn_hrnetv2p_w32_20e'
# load_from = None
# resume_from = '/epoch_36.pth'
# workflow = [('train', 1)]
#
# 2021-08-03 11:33:41,936 - mmdet - INFO - load model from: open-mmlab://msra/hrnetv2_w32
# 2021-08-03 11:33:50 Training - Training image download completed. Training in progress.2021-08-03 11:33:42,746 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: incre_modules.0.0.conv1.weight, incre_modules.0.0.bn1.weight, incre_modules.0.0.bn1.bias, incre_modules.0.0.bn1.running_mean, incre_modules.0.0.bn1.running_var, incre_modules.0.0.bn1.num_batches_tracked, incre_modules.0.0.conv2.weight, incre_modules.0.0.bn2.weight, incre_modules.0.0.bn2.bias, incre_modules.0.0.bn2.running_mean, incre_modules.0.0.bn2.running_var, incre_modules.0.0.bn2.num_batches_tracked, incre_modules.0.0.conv3.weight, incre_modules.0.0.bn3.weight, incre_modules.0.0.bn3.bias, incre_modules.0.0.bn3.running_mean, incre_modules.0.0.bn3.running_var, incre_modules.0.0.bn3.num_batches_tracked, incre_modules.0.0.downsample.0.weight, incre_modules.0.0.downsample.1.weight, incre_modules.0.0.downsample.1.bias, incre_modules.0.0.downsample.1.running_mean, incre_modules.0.0.downsample.1.running_var, incre_modules.0.0.downsample.1.num_batches_tracked, incre_modules.1.0.conv1.weight, incre_modules.1.0.bn1.weight, incre_modules.1.0.bn1.bias, incre_modules.1.0.bn1.running_mean, incre_modules.1.0.bn1.running_var, incre_modules.1.0.bn1.num_batches_tracked, incre_modules.1.0.conv2.weight, incre_modules.1.0.bn2.weight, incre_modules.1.0.bn2.bias, incre_modules.1.0.bn2.running_mean, incre_modules.1.0.bn2.running_var, incre_modules.1.0.bn2.num_batches_tracked, incre_modules.1.0.conv3.weight, incre_modules.1.0.bn3.weight, incre_modules.1.0.bn3.bias, incre_modules.1.0.bn3.running_mean, incre_modules.1.0.bn3.running_var, incre_modules.1.0.bn3.num_batches_tracked, incre_modules.1.0.downsample.0.weight, incre_modules.1.0.downsample.1.weight, incre_modules.1.0.downsample.1.bias, incre_modules.1.0.downsample.1.running_mean, incre_modules.1.0.downsample.1.running_var, incre_modules.1.0.downsample.1.num_batches_tracked, incre_modules.2.0.conv1.weight, incre_modules.2.0.bn1.weight, incre_modules.2.0.bn1.bias, incre_modules.2.0.bn1.running_mean, incre_modules.2.0.bn1.running_var, incre_modules.2.0.bn1.num_batches_tracked, incre_modules.2.0.conv2.weight, incre_modules.2.0.bn2.weight, incre_modules.2.0.bn2.bias, incre_modules.2.0.bn2.running_mean, incre_modules.2.0.bn2.running_var, incre_modules.2.0.bn2.num_batches_tracked, incre_modules.2.0.conv3.weight, incre_modules.2.0.bn3.weight, incre_modules.2.0.bn3.bias, incre_modules.2.0.bn3.running_mean, incre_modules.2.0.bn3.running_var, incre_modules.2.0.bn3.num_batches_tracked, incre_modules.2.0.downsample.0.weight, incre_modules.2.0.downsample.1.weight, incre_modules.2.0.downsample.1.bias, incre_modules.2.0.downsample.1.running_mean, incre_modules.2.0.downsample.1.running_var, incre_modules.2.0.downsample.1.num_batches_tracked, incre_modules.3.0.conv1.weight, incre_modules.3.0.bn1.weight, incre_modules.3.0.bn1.bias, incre_modules.3.0.bn1.running_mean, incre_modules.3.0.bn1.running_var, incre_modules.3.0.bn1.num_batches_tracked, incre_modules.3.0.conv2.weight, incre_modules.3.0.bn2.weight, incre_modules.3.0.bn2.bias, incre_modules.3.0.bn2.running_mean, incre_modules.3.0.bn2.running_var, incre_modules.3.0.bn2.num_batches_tracked, incre_modules.3.0.conv3.weight, incre_modules.3.0.bn3.weight, incre_modules.3.0.bn3.bias, incre_modules.3.0.bn3.running_mean, incre_modules.3.0.bn3.running_var, incre_modules.3.0.bn3.num_batches_tracked, incre_modules.3.0.downsample.0.weight, incre_modules.3.0.downsample.1.weight, incre_modules.3.0.downsample.1.bias, incre_modules.3.0.downsample.1.running_mean, incre_modules.3.0.downsample.1.running_var, incre_modules.3.0.downsample.1.num_batches_tracked, downsamp_modules.0.0.weight, downsamp_modules.0.0.bias, downsamp_modules.0.1.weight, downsamp_modules.0.1.bias, downsamp_modules.0.1.running_mean, downsamp_modules.0.1.running_var, downsamp_modules.0.1.num_batches_tracked, downsamp_modules.1.0.weight, downsamp_modules.1.0.bias, downsamp_modules.1.1.weight, downsamp_modules.1.1.bias, downsamp_modules.1.1.running_mean, downsamp_modules.1.1.running_var, downsamp_modules.1.1.num_batches_tracked, downsamp_modules.2.0.weight, downsamp_modules ...
#
# loading annotations into memory...
# Done (t=0.17s)
# creating index...
# index created!
# 2021-08-03 11:33:45,891 - mmdet - INFO - load checkpoint from /epoch_36.pth
# 2021-08-03 11:33:50,715 - mmdet - INFO - resumed epoch 36, iter 6156
# 2021-08-03 11:33:50,720 - mmdet - INFO - Start running, host: root@algo-1, work_dir: /opt/ml/model/Mmdetection/new_chunk_cascade_mask_rcnn_hrnetv2p_w32_20e
# 2021-08-03 11:33:50,720 - mmdet - INFO - workflow: [('train', 1)], max: 48 epochs
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# 2021-08-03 11:35:10,620 - mmdet - INFO - Epoch [37][50/171]#011lr: 0.00001, eta: 0:53:18, time: 1.598, data_time: 0.612, memory: 10762, loss_rpn_cls: 0.0581, loss_rpn_bbox: 0.0412, s0.loss_cls: 0.0697, s0.acc: 97.4609, s0.loss_bbox: 0.0587, s0.loss_mask: 0.1412, s1.loss_cls: 0.0352, s1.acc: 97.7118, s1.loss_bbox: 0.0662, s1.loss_mask: 0.0624, s2.loss_cls: 0.0215, s2.acc: 97.1663, s2.loss_bbox: 0.0432, s2.loss_mask: 0.0274, loss: 0.6246
# 2021-08-03 11:36:26,851 - mmdet - INFO - Epoch [37][100/171]#011lr: 0.00001, eta: 0:50:47, time: 1.525, data_time: 0.584, memory: 10762, loss_rpn_cls: 0.0477, loss_rpn_bbox: 0.0488, s0.loss_cls: 0.0756, s0.acc: 97.1074, s0.loss_bbox: 0.0667, s0.loss_mask: 0.1417, s1.loss_cls: 0.0392, s1.acc: 97.3340, s1.loss_bbox: 0.0724, s1.loss_mask: 0.0621, s2.loss_cls: 0.0224, s2.acc: 96.8919, s2.loss_bbox: 0.0475, s2.loss_mask: 0.0274, loss: 0.6515
# 2021-08-03 11:37:40,789 - mmdet - INFO - Epoch [37][150/171]#011lr: 0.00001, eta: 0:48:37, time: 1.479, data_time: 0.559, memory: 10922, loss_rpn_cls: 0.0435, loss_rpn_bbox: 0.0419, s0.loss_cls: 0.0737, s0.acc: 97.2188, s0.loss_bbox: 0.0671, s0.loss_mask: 0.1410, s1.loss_cls: 0.0390, s1.acc: 97.2045, s1.loss_bbox: 0.0737, s1.loss_mask: 0.0626, s2.loss_cls: 0.0224, s2.acc: 96.9061, s2.loss_bbox: 0.0460, s2.loss_mask: 0.0276, loss: 0.6384
# 2021-08-03 11:39:21,649 - mmdet - INFO - Epoch [38][50/171]#011lr: 0.00001, eta: 0:41:45, time: 1.446, data_time: 0.522, memory: 10922, loss_rpn_cls: 0.0366, loss_rpn_bbox: 0.0391, s0.loss_cls: 0.0660, s0.acc: 97.3984, s0.loss_bbox: 0.0625, s0.loss_mask: 0.1404, s1.loss_cls: 0.0330, s1.acc: 97.5425, s1.loss_bbox: 0.0681, s1.loss_mask: 0.0612, s2.loss_cls: 0.0193, s2.acc: 97.2671, s2.loss_bbox: 0.0448, s2.loss_mask: 0.0267, loss: 0.5979
# 2021-08-03 11:40:39,134 - mmdet - INFO - Epoch [38][100/171]#011lr: 0.00001, eta: 0:41:36, time: 1.550, data_time: 0.635, memory: 10922, loss_rpn_cls: 0.0295, loss_rpn_bbox: 0.0388, s0.loss_cls: 0.0637, s0.acc: 97.5430, s0.loss_bbox: 0.0573, s0.loss_mask: 0.1411, s1.loss_cls: 0.0307, s1.acc: 97.8085, s1.loss_bbox: 0.0600, s1.loss_mask: 0.0613, s2.loss_cls: 0.0182, s2.acc: 97.4619, s2.loss_bbox: 0.0395, s2.loss_mask: 0.0269, loss: 0.5669
# 2021-08-03 11:41:48,643 - mmdet - INFO - Epoch [38][150/171]#011lr: 0.00001, eta: 0:40:23, time: 1.390, data_time: 0.491, memory: 10922, loss_rpn_cls: 0.0300, loss_rpn_bbox: 0.0348, s0.loss_cls: 0.0659, s0.acc: 97.4199, s0.loss_bbox: 0.0558, s0.loss_mask: 0.1255, s1.loss_cls: 0.0323, s1.acc: 97.5659, s1.loss_bbox: 0.0610, s1.loss_mask: 0.0544, s2.loss_cls: 0.0188, s2.acc: 97.2782, s2.loss_bbox: 0.0421, s2.loss_mask: 0.0236, loss: 0.5442
